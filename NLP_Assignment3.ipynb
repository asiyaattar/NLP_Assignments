# %%
import pandas as pd

data = {
    "text": [
        "I love Natural Language Processing!",
        "NLP helps computers understand human language.",
        "Text cleaning is an important step in NLP."
    ],
    "label": ["positive", "positive", "neutral"]
}

df = pd.DataFrame(data)
df
# Out:
#                                              text     label
# 0             I love Natural Language Processing!  positive
# 1  NLP helps computers understand human language.  positive
# 2      Text cleaning is an important step in NLP.   neutral

# %%
import nltk
import re

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)  # remove punctuation & numbers
    text = re.sub(r'\s+', ' ', text)      # remove extra spaces
    return text.strip()

df["cleaned_text"] = df["text"].apply(clean_text)
df
# Out:
#                                              text     label  \
# 0             I love Natural Language Processing!  positive
# 1  NLP helps computers understand human language.  positive
# 2      Text cleaning is an important step in NLP.   neutral
#
#                                     cleaned_text
# 0             i love natural language processing
# 1  nlp helps computers understand human language
# 2      text cleaning is an important step in nlp

# %%
import nltk
nltk.download('punkt_tab')

stop_words = set(stopwords.words("english"))

def remove_stopwords(text):
    words = word_tokenize(text)
    words = [word for word in words if word not in stop_words]
    return " ".join(words)

df["no_stopwords"] = df["cleaned_text"].apply(remove_stopwords)
df
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
#                                              text     label  \
# 0             I love Natural Language Processing!  positive
# 1  NLP helps computers understand human language.  positive
# 2      Text cleaning is an important step in NLP.   neutral
#
#                                     cleaned_text  \
# 0             i love natural language processing
# 1  nlp helps computers understand human language
# 2      text cleaning is an important step in nlp
#
#                                     no_stopwords
# 0               love natural language processing
# 1  nlp helps computers understand human language
# 2               text cleaning important step nlp

# %%
lemmatizer = WordNetLemmatizer()

def lemmatize_text(text):
    words = word_tokenize(text)
    words = [lemmatizer.lemmatize(word) for word in words]
    return " ".join(words)

df["lemmatized_text"] = df["no_stopwords"].apply(lemmatize_text)
df
# Out:
#                                              text     label  \
# 0             I love Natural Language Processing!  positive
# 1  NLP helps computers understand human language.  positive
# 2      Text cleaning is an important step in NLP.   neutral
#
#                                     cleaned_text  \
# 0             i love natural language processing
# 1  nlp helps computers understand human language
# 2      text cleaning is an important step in nlp
#
#                                     no_stopwords  \
# 0               love natural language processing
# 1  nlp helps computers understand human language
# 2               text cleaning important step nlp
#
#                                lemmatized_text
# 0             love natural language processing
# 1  nlp help computer understand human language
# 2             text cleaning important step nlp

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df["label_encoded"] = label_encoder.fit_transform(df["label"])
df
# Out:
#                                              text     label  \
# 0             I love Natural Language Processing!  positive
# 1  NLP helps computers understand human language.  positive
# 2      Text cleaning is an important step in NLP.   neutral
#
#                                     cleaned_text  \
# 0             i love natural language processing
# 1  nlp helps computers understand human language
# 2      text cleaning is an important step in nlp
#
#                                     no_stopwords  \
# 0               love natural language processing
# 1  nlp helps computers understand human language
# 2               text cleaning important step nlp
#
#                                lemmatized_text  label_encoded
# 0             love natural language processing              1
# 1  nlp help computer understand human language              1
# 2             text cleaning important step nlp              0

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(df["lemmatized_text"])

tfidf_df = pd.DataFrame(
    tfidf_matrix.toarray(),
    columns=tfidf.get_feature_names_out()
)

tfidf_df
# Out:
#    cleaning  computer      help     human  important  language      love  \
# 0  0.000000  0.000000  0.000000  0.000000   0.000000  0.402040  0.528635
# 1  0.000000  0.440362  0.440362  0.440362   0.000000  0.334907  0.000000
# 2  0.467351  0.000000  0.000000  0.000000   0.467351  0.000000  0.000000
#
#     natural       nlp  processing      step      text  understand
# 0  0.528635  0.000000    0.528635  0.000000  0.000000    0.000000
# 1  0.000000  0.334907    0.000000  0.000000  0.000000    0.440362
# 2  0.000000  0.355432    0.000000  0.467351  0.467351    0.000000

# %%
df.to_csv("cleaned_text_data.csv", index=False)

# %%
tfidf_df.to_csv("tfidf_features.csv", index=False)
